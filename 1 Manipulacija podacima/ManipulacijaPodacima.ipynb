# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd #za citanje podataka

# %%
data = pd.read_csv("../Data/Housing.csv")
data.head(10) #prikaz prvih 10 redova
# Out:
#       price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000   7420         4          2        3      yes        no       no
# 1  12250000   8960         4          4        4      yes        no       no
# 2  12250000   9960         3          2        2      yes        no      yes
# 3  12215000   7500         4          2        2      yes        no      yes
# 4  11410000   7420         4          1        2      yes       yes      yes
# 5  10850000   7500         3          3        1      yes        no      yes
# 6  10150000   8580         4          3        4      yes        no       no
# 7  10150000  16200         5          3        2      yes        no       no
# 8   9870000   8100         4          1        2      yes       yes      yes
# 9   9800000   5750         3          2        4      yes       yes       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %% [markdown]
# **Dimenzionalnost seta podataka**

# %%
data.shape
# Out:
# (545, 13)

# %% [markdown]
# **Popis index vrijednosti redova dataframe-a**

# %%
data.index
# Out:
# RangeIndex(start=0, stop=545, step=1)

# %% [markdown]
# **Informacije o setu podatka**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %% [markdown]
# **Pristup pojedinacnim redovima**

# %%
data.iloc[[5]] # index location
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 5  10850000  7500         3          3        1      yes        no      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 5              no             yes        2      yes   semi-furnished

# %%
data.iloc[[2,5]] # vrati drugi i peti red
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 2  12250000  9960         3          2        2      yes        no      yes
# 5  10850000  7500         3          3        1      yes        no      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 2              no              no        2      yes   semi-furnished
# 5              no             yes        2      yes   semi-furnished

# %% [markdown]
# Pristup pojedinacnim kolonama

# %%
data.iloc[:,[3]] #: oznacava uzmi mi sve redove, i samo trecu kolonu
# Out:
#      bathrooms
# 0            2
# 1            4
# 2            2
# 3            2
# 4            1
# ..         ...
# 540          1
# 541          1
# 542          1
# 543          1
# 544          1
#
# [545 rows x 1 columns]

# %%
data.iloc[10:-5,[1,2,3]] # vraca sve redove od 10 do ukupno-5, i kolone 1,2,3
# Out:
#       area  bedrooms  bathrooms
# 10   13200         3          1
# 11    6000         4          3
# 12    6550         4          2
# 13    3500         4          2
# 14    7800         3          2
# ..     ...       ...        ...
# 535   3360         2          1
# 536   3420         5          1
# 537   1700         3          1
# 538   3649         2          1
# 539   2990         2          1
#
# [530 rows x 3 columns]

# %% [markdown]
# Pristup pojedinacnim kolonama na osnovu imena

# %%
data["bathrooms"]
# Out:
# 0      2
# 1      4
# 2      2
# 3      2
# 4      1
#       ..
# 540    1
# 541    1
# 542    1
# 543    1
# 544    1
# Name: bathrooms, Length: 545, dtype: int64

# %% [markdown]
# Pristup pojedinacnim vrijednostima

# %%
# ako hocemo tacno neku poziciju
data.iloc[[5],[3]]
# na ovaj nacin mozemo i promjeniti vrijednost u tabeli
# data.iloc[[5],[3]] = 10
# Out:
#    bathrooms
# 5          3

# %%
data["bathrooms"][5]
# Out:
# 3

# %% [markdown]
# Prikaz dijela seta podataka na osnovu uslova nad vrijednostima neke kolone

# %%
data.loc[data["price"] > 10000000].head(20)
# Out:
#       price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000   7420         4          2        3      yes        no       no
# 1  12250000   8960         4          4        4      yes        no       no
# 2  12250000   9960         3          2        2      yes        no      yes
# 3  12215000   7500         4          2        2      yes        no      yes
# 4  11410000   7420         4          1        2      yes       yes      yes
# 5  10850000   7500         3          3        1      yes        no      yes
# 6  10150000   8580         4          3        4      yes        no       no
# 7  10150000  16200         5          3        2      yes        no       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# ...

# %% [markdown]
# Pomocu upita

# %%
data.query("price>10000000 and area<10000")
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
# 5  10850000  7500         3          3        1      yes        no      yes
# 6  10150000  8580         4          3        4      yes        no       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# ...

# %%
len(data.loc[data["price"] > 10000000]) # koliko ih ukupono ima
# Out:
# 8

# %% [markdown]
# Brisanje kolone iz dataseta

# %%
data = data.drop(columns = ['hotwaterheating']) # ili data.drop[columns="hotwaterheating", inpleace=True]
data.head(5)
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   airconditioning  parking prefarea furnishingstatus
# 0             yes        2      yes        furnished
# 1             yes        3       no        furnished
# 2              no        2      yes   semi-furnished
# 3             yes        3      yes        furnished
# 4             yes        2       no        furnished

# %% [markdown]
# Vrijednosti kategoricnih varijabli

# %%
data["mainroad"].value_counts()
# Out:
# yes    468
# no      77
# Name: mainroad, dtype: int64

# %% [markdown]
# **Osobine brojčanih varijabli**

# %%
data.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %% [markdown]
# **Histogrami brojčanih varijabli**

# %%
data.hist(bins=50, figsize = (20,15)) #bins koliko su grafici tanki
plt.show()

# %% [markdown]
# **Grafici**

# %%
data.plot(x='price', y='area', style='o')
# Out:
# <Axes: xlabel='price'>

# %%
data.loc[data['mainroad'] == "yes", ["mainroad"]] = 1

# %%
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3        1        no       no
# 1    12250000  8960         4          4        4        1        no       no
# 2    12250000  9960         3          2        2        1        no      yes
# 3    12215000  7500         4          2        2        1        no      yes
# 4    11410000  7420         4          1        2        1       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1        1        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1        1        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2        1        no       no
#
# ...

# %%
data.loc[data['mainroad'] == "no", ["mainroad"]] = 0
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3        1        no       no
# 1    12250000  8960         4          4        4        1        no       no
# 2    12250000  9960         3          2        2        1        no      yes
# 3    12215000  7500         4          2        2        1        no      yes
# 4    11410000  7420         4          1        2        1       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1        1        no      yes
# 541   1767150  2400         3          1        1        0        no       no
# 542   1750000  3620         2          1        1        1        no       no
# 543   1750000  2910         3          1        1        0        no       no
# 544   1750000  3850         3          1        2        1        no       no
#
# ...

# %%
data.plot(x='price', y='mainroad', style='o')
# Out:
# <Axes: xlabel='price'>

# %%
plt.scatter(data["price"], data["basement"].astype(str))

# %% [markdown]
# Priprema podataka

# %% [markdown]
# **Pravljenje testnog seta podataka**

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(data, test_size=0.2, random_state=42)
test_set.head()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 316  4060000  5900         4          2        2        0        no      yes
# 77   6650000  6500         3          2        3        1        no       no
# 360  3710000  4040         2          1        1        1        no       no
# 90   6440000  5000         3          1        2        1        no       no
# 493  2800000  3960         3          1        1        1        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 316              no              no        1       no      unfurnished
# 77               no             yes        0      yes        furnished
# 360              no              no        0       no   semi-furnished
# 90               no             yes        0       no   semi-furnished
# 493              no              no        0       no        furnished

# %%
# ili pomocu pandas biblioteke
data_copy = data.copy()
train_set = data_copy.sample(frac=0.8, random_state=42)
test_set = data_copy.drop(train_set.index)
test_set.head()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 1   12250000  8960         4          4        4        1        no       no
# 8    9870000  8100         4          1        2        1       yes      yes
# 13   9240000  3500         4          2        2        1        no       no
# 14   9240000  7800         3          2        2        1        no       no
# 20   8750000  4320         3          1        2        1        no      yes
#
#    hotwaterheating airconditioning  parking prefarea furnishingstatus
# 1               no             yes        3       no        furnished
# 8               no             yes        2      yes        furnished
# 13             yes              no        2       no        furnished
# 14              no              no        0      yes   semi-furnished
# 20             yes              no        2       no   semi-furnished

# %%
# ili pomocu numpy biblioteke
mask = np.random.rand(len(data)) < 0.8
train_set = data[mask]
test_set = data[~mask]
test_set.head()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 5   10850000  7500         3          3        1        1        no      yes
# 12   9310000  6550         4          2        2        1        no       no
# 13   9240000  3500         4          2        2        1        no       no
# 14   9240000  7800         3          2        2        1        no       no
# 23   8645000  4560         3          2        2        1       yes      yes
#
#    hotwaterheating airconditioning  parking prefarea furnishingstatus
# 5               no             yes        2      yes   semi-furnished
# 12              no             yes        1      yes   semi-furnished
# 13             yes              no        2       no        furnished
# 14              no              no        0      yes   semi-furnished
# 23              no             yes        1       no        furnished

# %% [markdown]
# **Priprema podataka prije treniranja**

# %% [markdown]
# **Čišćenje podataka**

# %%
data.isnull().values.any()
# Out:
# False

# %%
data.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64
